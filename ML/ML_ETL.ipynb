# %% [markdown]
# # **ETL_Archivos YELP**

# %% [markdown]
# **Archivo Busines.pkl**

# %% [markdown]
# Librerias a usar para leer el archivo:

# %%
import pandas as pd
import json

# %%
df = pd.read_pickle("Yelp/business.pkl")
df.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# ...

# %% [markdown]
# visualizar el tipo de variable de cada columna:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %% [markdown]
# como hay columnas dupicadas:

# %% [markdown]
# eliminamos las columnas duplicadas:

# %%
df_sin_duplicados = df.loc[:, ~df.columns.duplicated()]

# %%
df_sin_duplicados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: object(14)
# memory usage: 17.2+ MB

# %%
data=pd.DataFrame(df_sin_duplicados)

# %% [markdown]
# Buscamos locales de la franquicia mc donalds en la columna name :

# %%
resultados = data[data['name'].str.contains('McDonald', case=False)]
resultados.head()
# Out:
#                 business_id        name              address        city  \
# 193  yM8LlTInbQH4FwWC97lz6w  McDonald's     1919 S Jefferson   St. Louis
# 361  aNXw3PkXVt8ANwLyCfcmpg  McDonald's        2333 Welsh Rd    Lansdale
# 460  gb7JjRJtzWDsIWpJihZhBQ  McDonald's       417 N Broadway  Pennsville
# 514  9qxMhGWjGsuPUoQB3Y74Wg  McDonald's        1119 N Tucker   St. Louis
# 646  A1lAqN3SOaBLoo6NqVcy4Q  McDonald's  11110 Causeway Blvd     Brandon
#
#     state postal_code   latitude  longitude stars review_count is_open  \
# 193    PA       63104  38.612495 -90.221942   1.5          100       1
# 361    NJ       19446  40.263706 -75.317916   1.5           17       1
# 460    AZ       08070  39.677302   -75.4954   2.0           20       1
# 514    MO       63101  38.636908 -90.195483   1.5           62       1
# 646    MO       33511  27.925332 -82.325395   2.0            6       1
#
#                                             attributes  \
# ...

# %%
resultados = resultados.assign(categories = resultados.categories.str.split(', ')).explode('categories')
resultados.head()
# Out:
#                 business_id        name           address       city state  \
# 193  yM8LlTInbQH4FwWC97lz6w  McDonald's  1919 S Jefferson  St. Louis    PA
# 193  yM8LlTInbQH4FwWC97lz6w  McDonald's  1919 S Jefferson  St. Louis    PA
# 193  yM8LlTInbQH4FwWC97lz6w  McDonald's  1919 S Jefferson  St. Louis    PA
# 193  yM8LlTInbQH4FwWC97lz6w  McDonald's  1919 S Jefferson  St. Louis    PA
# 193  yM8LlTInbQH4FwWC97lz6w  McDonald's  1919 S Jefferson  St. Louis    PA
#
#     postal_code   latitude  longitude stars review_count is_open  \
# 193       63104  38.612495 -90.221942   1.5          100       1
# 193       63104  38.612495 -90.221942   1.5          100       1
# 193       63104  38.612495 -90.221942   1.5          100       1
# 193       63104  38.612495 -90.221942   1.5          100       1
# 193       63104  38.612495 -90.221942   1.5          100       1
#
#                                             attributes    categories  \
# ...

# %% [markdown]
# Guardamos en un archivo csv los datos de las franquicias mc donalds:

# %%
resultados.to_csv('bussines_yelp.csv',index=False)

# %% [markdown]
# **REVIEW.JSON**

# %% [markdown]
# abrimos el archivo json en partes con el siguiente codigo :

# %%
chunk_size = 5000  # Adjust this based on your memory availability
json_reader = pd.read_json('review.json', lines=True, chunksize=chunk_size)
df_list = []
for chunk in json_reader:
    df_list.append(chunk)
df_rev = pd.concat(df_list, ignore_index=True)

# %%
df_rev.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# ...

# %%
df_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        int64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 480.0+ MB

# %% [markdown]
# eliminamos duplicados de las columnas 'review_id' y 'text':

# %%
df_rev=df_rev.drop_duplicates(subset=['review_id','text'],keep="first")
df_rev['id_review']=df_rev.index

# %%
df_rev.drop(['useful','funny','cool'],axis=1,inplace=True)

# %%
df_rev.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars                                               text  \
# 0      3  If you decide to eat here, just be aware it is...
# 1      5  I've taken a lot of spin classes over the year...
# 2      3  Family diner. Had the buffet. Eclectic assortm...
# 3      5  Wow!  Yummy, different,  delicious.   Our favo...
# 4      4  Cute interior and owner (?) gave us tour of up...
#
#                  date  id_review
# 0 2018-07-07 22:09:11          0
# 1 2012-01-03 15:28:18          1
# 2 2014-02-05 20:30:30          2
# ...

# %% [markdown]
# Divide la columna date en hora y fecha

# %%
df_rev['hour'] = pd.to_datetime(df_rev['date']).dt.strftime('%H:%M:%S')

df_rev['date'] = pd.to_datetime(df_rev['date']).dt.strftime('%Y-%m-%d')

# %%
df_rev.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars                                               text        date  \
# 0      3  If you decide to eat here, just be aware it is...  2018-07-07
# 1      5  I've taken a lot of spin classes over the year...  2012-01-03
# 2      3  Family diner. Had the buffet. Eclectic assortm...  2014-02-05
# 3      5  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04
# 4      4  Cute interior and owner (?) gave us tour of up...  2017-01-14
#
#    id_review      hour
# 0          0  22:09:11
# 1          1  15:28:18
# ...

# %%
for chunk in df_rev:
    year_to_filter = '2016'
    filtered_df = df_rev[df_rev['date'].str.startswith(year_to_filter)]
    chunk_filter = filtered_df[filtered_df['date'] > year_to_filter] 
    chunk_filter=chunk_filter.drop(['review_id','id_review'],axis=1)
    chunk_filter.to_parquet('review_yelp.parquet',  compression="snappy")

# %%
yelp = resultados.merge(chunk_filter, on='business_id', how='inner')
yelp.head()

# %%
yelp.to_csv('BUSINESS_YELP_YORK.csv')
